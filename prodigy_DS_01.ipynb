# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikresi/PRODIGY_DS_01/blob/main/prodigy_DS_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
import zipfile
import os

# Define the path to the uploaded zip file and extract its contents
# Make sure the path is correct and the file exists.
zip_file_path = '/content/API_SP.POP.TOTL_DS2_en_csv_v2_3401680.zip'
extract_dir = '/mnt/data/extracted_files'

# Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# List the extracted files to see what we have
extracted_files = os.listdir(extract_dir)
extracted_files
import pandas as pd

# Load the main data file
data_file_path = os.path.join(extract_dir, 'API_SP.POP.TOTL_DS2_en_csv_v2_3401680.csv')
population_data = pd.read_csv(data_file_path, skiprows=4)  # Skip metadata rows at the top

# Display the first few rows to understand its structure
population_data.head()
# Select a few countries for the bar chart
selected_countries = population_data[['Country Name', '2023']].dropna().sort_values(by='2023', ascending=False).head(10)

# Create the bar chart
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(selected_countries['Country Name'], selected_countries['2023'], color='skyblue')
plt.xlabel('Country')
plt.ylabel('Population in 2023')
plt.title('Top 10 Countries by Population in 2023')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
